# %% [markdown]
# ## Lecture 0: Functions, Variables

# %%
input("what's your name")
print("hello,world")

# %%
name=input("what's your name")
print("hello")
print(name)
# Out:
# wahat's your name caihongyu
# hello
# caihongyu

# %%
name=input("what's your name")
print("hello, "+ name)
# Out:
# what's your name caihongyu
# hello, caihongyu

# %%
name=input("what's your name")
# print function have parameter end
print("hello, ", end="")
print(name)
# Out:
# what's your name caihongyu
# hello, caihongyu

# %%
name=input("what's your name")
# print function have parameter sep
print("hello," , name , sep="???" )
# Out:
# what's your name caihongyu
# hello,???caihongyu

# %%
print("hello, \"friend\"")
# Out:
# hello, "friend"

# %%
name=input("what's your name")
# f must be placed immediately before the quotation mark
print( f"hello, {name}")
# Out:
# what's your name caihongyu
# hello, caihongyu

# %%
name=input("what's your name")
name=name.strip() # remove whitespace from str
name=name.capitalize() # capitalize user's name
print(f"hello, {name}")
# split user's name to first name and lastname
# Out:
# what's your name    caihong yu
# hello, Caihong yu

# %%
name=input("what's your name")
# split user's name to first name and lastname
first,last=name.split(" ")
print(f"hello, {first}")
# Out:
# what's your name caihong yu
# hello, caihong

# %%
# caculator 
x=input("waht's x")
y=input("what's y")
z=int(x)+int(y)
print(z)
# Out:
# waht's x 1
# what's y 2
# 3

# %%
x=int(input("waht's x"))
y=int(input("what's y"))
print(x+y)
# Out:
# waht's x 1
# what's y 2
# 3

# %%
x=float(input("what's x"))
y=float(input("what's y"))
z=round(x+y)
print(z)
# Out:
# what's x 1.2
# what's y 3.4
# 5

# %%
x=float(input("what's x"))
y=float(input("what's y"))
z=round(x+y)
print(f"{z:,}")
# Out:
# what's x 1
# what's y 999
# 1,000

# %%
x=float(input("what's x"))
y=float(input("what's y"))

# z=round(x / y, 2)
# print(z)

z=x/y
print(f"{z:.2f}")
# Out:
# what's x 2
# what's y 3
# 0.67

# %%
# functions
def hello(to="world"):
    print("hello," , to)

hello()

name=input("what's your name")
hello(name)
# Out:
# hello, world
# what's your name caihongyu
# hello, caihongyu

# %%
def main():
    name=input("what's your name")
    hello(name)

def hello(to="world"):
    print("hello," , to)

main()
# Out:
# what's your name
# hello,

# %%
def main():
    x=int(input("what's x"))
    print("x squared is" , squared(x))

def squared(n):
    return n * n
    

main()
# Out:
# what's x 5
# x squared is 25

# %% [markdown]
# ## Lecture 1: Conditionals

# %%
# compare
x=int(input("what's x"))
y=int(input("what's y"))

if x > y:
    print("x is greater than y")

elif x < y:
    print("x is less than y")

else:
    print("x is equal to y")
# Out:
# what's x 2
# what's y 3
# x is less than y

# %%
# compare "or"
x=int(input("what's x"))
y=int(input("what's y"))

if x > y or x < y:
    print("x is not equal to y")

else:
    print("x is equal to y")
# Out:
# what's x 2
# what's y 2
# x is equal to y

# %%
# grade "and"
score=int(input("score: "))

if score >=90 and score <= 100: # 90 <= score <= 100
    print("grade: A")

elif score >= 80 and score < 90:
    print("scorez: B")
# Out:
# score:  100
# grade: A

# %%
# parity

x=int(input("what's x? "))

if x % 2 == 0:
    print("Even")

else:  
    print("Odd")
# Out:
# what's x?  12
# Even

# %%
def main():
    x=int(input("what's x"))
    if is_even(x):
        print("Even")
    else:
        print("Odd")

def is_even(n):
    return (n % 2 == 0)
    # if n % 2 == 0:
    #     return True
    # else:
    #     return False

main()
# Out:
# what's x 20
# Even
