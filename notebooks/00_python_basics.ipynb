# %% [markdown]
# Day 2 · Python基础练习
# 学习变量、函数、input用法

# %%
input("what's your name")
print("hello,world")
# Out:
# what's your name caihongyu
# hello,world

# %%
name=input("wahat's your name")
print("hello")
print(name)
# Out:
# wahat's your name caihongyu
# hello
# caihongyu

# %%
name=input("what's your name")
print("hello, "+ name)
# Out:
# what's your name caihongyu
# hello, caihongyu
