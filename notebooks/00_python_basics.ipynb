# %% [markdown]
# Day 2 · Python basic practice

# %%
input("what's your name")
print("hello,world")
# Out:
# what's your name caihongyu
# hello,world

# %%
name=input("wahat's your name")
print("hello")
print(name)
# Out:
# wahat's your name caihongyu
# hello
# caihongyu

# %%
name=input("what's your name")
print("hello, "+ name)
# Out:
# what's your name caihongyu
# hello, caihongyu

# %% [markdown]
# print function have parameter end

# %%
name=input("what's your name")
print("hello, ", end="")
print(name)
# Out:
# what's your name caihongyu
# hello, caihongyu

# %% [raw]
# print function have parameter sep

# %%
name=input("what's your name")
print("hello," , name , sep="???" )
# Out:
# what's your name caihongyu
# hello,???caihongyu

# %%
print("hello, \"friend\"")
# Out:
# hello, "friend"
